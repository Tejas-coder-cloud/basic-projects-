# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejas-coder-cloud/basic-projects-/blob/main/Bivariate_Analysis_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
tips =sns.load_dataset('titanic.csv')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2733268802.py in <cell line: 0>()
# ----> 1 tips =sns.load_dataset('titanic.csv')
#
# /usr/local/lib/python3.12/dist-packages/seaborn/utils.py in load_dataset(name, cache, data_home, **kws)
#     571         if not os.path.exists(cache_path):
#     572             if name not in get_dataset_names():
# --> 573                 raise ValueError(f"'{name}' is not one of the example datasets.")
#     574             urlretrieve(url, cache_path)
#     575         full_path = cache_path
#
# ValueError: 'titanic.csv' is not one of the example datasets.

# %%
from google.colab import drive
drive.mount('/content/drive')
